# %% [markdown]
# ## Learning Rate Schedule For Training Models
# Adapting the learning rate for your stochastic gradient descent optimization procedure can increase performance and reduce training time.
# 1. Decrease the learning rate gradually based on the epoch.
# 2. Decrease the learning rate using punctuated large drops at specific epochs.
#
# ### Time based learning rate schedule
# Keras has a time-based learning rate schedule built in. The stochastic gradient descent optimiza- tion algorithm implementation in the SGD class has an argument called decay. This argument is used in the time-based learning rate decay schedule equation as follows:
# ![Screen%20Shot%202018-06-17%20at%202.48.25%20PM.png](attachment:Screen%20Shot%202018-06-17%20at%202.48.25%20PM.png)

# %%
# time based learning rate decay
from pandas import read_csv
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from sklearn.preprocessing import LabelEncoder
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
np.random.seed(7)

#load dataset
dataframe = read_csv("Accessory_files/ionosphere.csv", header = None)
dataset = dataframe.values

#split the inputs
X = dataset[:,0:34].astype(float)
Y = dataset[:,34]

#encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

#create model
model = Sequential()
model.add(Dense(34, input_dim = 34, kernel_initializer='normal', activation='relu'))
model.add(Dense(1,kernel_initializer='normal',activation='sigmoid'))

#compile
epochs = 50
learning_rate = 0.1
decay_rate = learning_rate/epochs
momentum=0.9
sgd = SGD(lr = learning_rate, momentum=momentum, decay = decay_rate, nesterov=False)
model.compile(loss = 'binary_crossentropy', optimizer = sgd, metrics=['accuracy'])

model.fit(X,encoded_Y, validation_split=0.33, epochs=epochs, batch_size=28, verbose=2)
# Out:
# Train on 235 samples, validate on 116 samples
# Epoch 1/50
#  - 0s - loss: 0.6803 - acc: 0.6468 - val_loss: 0.6203 - val_acc: 0.9138
# Epoch 2/50
#  - 0s - loss: 0.6201 - acc: 0.7234 - val_loss: 0.4763 - val_acc: 0.8707
# Epoch 3/50
#  - 0s - loss: 0.5015 - acc: 0.8298 - val_loss: 0.3793 - val_acc: 0.9397
# Epoch 4/50
#  - 0s - loss: 0.3668 - acc: 0.8553 - val_loss: 0.3906 - val_acc: 0.8621
# Epoch 5/50
#  - 0s - loss: 0.2855 - acc: 0.8681 - val_loss: 0.1530 - val_acc: 0.9655
# Epoch 6/50
#  - 0s - loss: 0.2199 - acc: 0.9277 - val_loss: 0.2410 - val_acc: 0.9310
# Epoch 7/50
#  - 0s - loss: 0.1848 - acc: 0.9362 - val_loss: 0.1411 - val_acc: 0.9655
# Epoch 8/50
#  - 0s - loss: 0.1685 - acc: 0.9277 - val_loss: 0.0920 - val_acc: 0.9741
# Epoch 9/50
#  - 0s - loss: 0.1763 - acc: 0.9362 - val_loss: 0.2079 - val_acc: 0.9397
# Epoch 10/50
#  - 0s - loss: 0.1451 - acc: 0.9404 - val_loss: 0.1241 - val_acc: 0.9828
# Epoch 11/50
#  - 0s - loss: 0.1261 - acc: 0.9532 - val_loss: 0.0829 - val_acc: 0.9914
# Epoch 12/50
#  - 0s - loss: 0.1182 - acc: 0.9617 - val_loss: 0.0681 - val_acc: 0.9741
# Epoch 13/50
#  - 0s - loss: 0.1399 - acc: 0.9447 - val_loss: 0.0890 - val_acc: 0.9914
# Epoch 14/50
#  - 0s - loss: 0.1104 - acc: 0.9617 - val_loss: 0.1195 - val_acc: 0.9741
# Epoch 15/50
#  - 0s - loss: 0.0950 - acc: 0.9660 - val_loss: 0.0605 - val_acc: 0.9828
# Epoch 16/50
#  - 0s - loss: 0.0973 - acc: 0.9617 - val_loss: 0.1153 - val_acc: 0.9914
# Epoch 17/50
#  - 0s - loss: 0.0885 - acc: 0.9745 - val_loss: 0.0769 - val_acc: 0.9828
# Epoch 18/50
#  - 0s - loss: 0.0822 - acc: 0.9745 - val_loss: 0.0760 - val_acc: 0.9914
# Epoch 19/50
#  - 0s - loss: 0.0700 - acc: 0.9830 - val_loss: 0.0717 - val_acc: 0.9914
# Epoch 20/50
#  - 0s - loss: 0.0694 - acc: 0.9830 - val_loss: 0.0759 - val_acc: 0.9914
# Epoch 21/50
#  - 0s - loss: 0.0631 - acc: 0.9830 - val_loss: 0.0647 - val_acc: 0.9914
# Epoch 22/50
#  - 0s - loss: 0.0601 - acc: 0.9830 - val_loss: 0.0701 - val_acc: 0.9914
# Epoch 23/50
#  - 0s - loss: 0.0589 - acc: 0.9830 - val_loss: 0.0683 - val_acc: 0.9914
# Epoch 24/50
#  - 0s - loss: 0.0558 - acc: 0.9872 - val_loss: 0.0590 - val_acc: 0.9914
# Epoch 25/50
#  - 0s - loss: 0.0596 - acc: 0.9872 - val_loss: 0.0747 - val_acc: 0.9914
# Epoch 26/50
#  - 0s - loss: 0.0523 - acc: 0.9872 - val_loss: 0.0594 - val_acc: 0.9914
# Epoch 27/50
#  - 0s - loss: 0.0500 - acc: 0.9872 - val_loss: 0.0706 - val_acc: 0.9914
# Epoch 28/50
#  - 0s - loss: 0.0474 - acc: 0.9872 - val_loss: 0.0623 - val_acc: 0.9914
# Epoch 29/50
#  - 0s - loss: 0.0446 - acc: 0.9872 - val_loss: 0.0616 - val_acc: 0.9914
# Epoch 30/50
#  - 0s - loss: 0.0454 - acc: 0.9872 - val_loss: 0.0601 - val_acc: 0.9914
# Epoch 31/50
#  - 0s - loss: 0.0454 - acc: 0.9872 - val_loss: 0.0658 - val_acc: 0.9914
# Epoch 32/50
#  - 0s - loss: 0.0415 - acc: 0.9872 - val_loss: 0.0577 - val_acc: 0.9914
# Epoch 33/50
#  - 0s - loss: 0.0396 - acc: 0.9872 - val_loss: 0.0639 - val_acc: 0.9914
# Epoch 34/50
#  - 0s - loss: 0.0416 - acc: 0.9872 - val_loss: 0.0630 - val_acc: 0.9914
# Epoch 35/50
#  - 0s - loss: 0.0394 - acc: 0.9915 - val_loss: 0.0617 - val_acc: 0.9914
# Epoch 36/50
#  - 0s - loss: 0.0372 - acc: 0.9957 - val_loss: 0.0558 - val_acc: 0.9914
# Epoch 37/50
#  - 0s - loss: 0.0361 - acc: 0.9957 - val_loss: 0.0633 - val_acc: 0.9914
# Epoch 38/50
#  - 0s - loss: 0.0367 - acc: 0.9957 - val_loss: 0.0590 - val_acc: 0.9914
# Epoch 39/50
#  - 0s - loss: 0.0393 - acc: 0.9915 - val_loss: 0.0520 - val_acc: 0.9914
# Epoch 40/50
#  - 0s - loss: 0.0364 - acc: 0.9957 - val_loss: 0.0644 - val_acc: 0.9914
# Epoch 41/50
#  - 0s - loss: 0.0364 - acc: 0.9915 - val_loss: 0.0561 - val_acc: 0.9914
# Epoch 42/50
#  - 0s - loss: 0.0327 - acc: 0.9957 - val_loss: 0.0603 - val_acc: 0.9914
# Epoch 43/50
#  - 0s - loss: 0.0335 - acc: 0.9915 - val_loss: 0.0602 - val_acc: 0.9914
# Epoch 44/50
#  - 0s - loss: 0.0335 - acc: 0.9957 - val_loss: 0.0557 - val_acc: 0.9914
# Epoch 45/50
#  - 0s - loss: 0.0328 - acc: 0.9957 - val_loss: 0.0616 - val_acc: 0.9914
# Epoch 46/50
#  - 0s - loss: 0.0334 - acc: 0.9915 - val_loss: 0.0558 - val_acc: 0.9914
# Epoch 47/50
#  - 0s - loss: 0.0368 - acc: 0.9915 - val_loss: 0.0539 - val_acc: 0.9914
# Epoch 48/50
#  - 0s - loss: 0.0366 - acc: 0.9957 - val_loss: 0.0515 - val_acc: 0.9914
# Epoch 49/50
#  - 0s - loss: 0.0295 - acc: 0.9957 - val_loss: 0.0722 - val_acc: 0.9914
# Epoch 50/50
#  - 0s - loss: 0.0297 - acc: 0.9957 - val_loss: 0.0550 - val_acc: 0.9914

# %% [markdown]
# ### Drop Based Learning Rate Schedule
# nother popular learning rate schedule used with deep learning models is to systematically drop the learning rate at specific times during training. Often this method is implemented by dropping the learning rate by half every fixed number of epochs. For example, we may have an initial learning rate of 0.1 and drop it by a factor of 0.5 every 10 epochs. The first 10 epochs of training would use a value of 0.1, in the next 10 epochs a learning rate of 0.05 would be used, and so on. If we plot out the learning rates for this example out to 100 epochs you get the graph below showing learning rate (y-axis) versus epoch (x-axis).
# ![Screen%20Shot%202018-06-17%20at%203.05.07%20PM.png](attachment:Screen%20Shot%202018-06-17%20at%203.05.07%20PM.png)
# ![Screen%20Shot%202018-06-17%20at%203.03.30%20PM.png](attachment:Screen%20Shot%202018-06-17%20at%203.03.30%20PM.png)

# %%
from keras.callbacks import LearningRateScheduler
import math

# %%
# learning rate schedule
def step_decay(epoch):
  initial_lrate = 0.1
  drop = 0.5
  epochs_drop = 10.0
  lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
  return lrate

# %%
np.random.seed(7)

#load dataset
dataframe = read_csv("Accessory_files/ionosphere.csv", header = None)
dataset = dataframe.values

#split the inputs
X = dataset[:,0:34].astype(float)
Y = dataset[:,34]

#encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

#create model
model = Sequential()
model.add(Dense(34, input_dim = 34, kernel_initializer='normal', activation='relu'))
model.add(Dense(1,kernel_initializer='normal',activation='sigmoid'))

#compile
sgd = SGD(lr = 0.0, momentum=0.9, decay = 0.0, nesterov=False)
model.compile(loss = 'binary_crossentropy', optimizer = sgd, metrics=['accuracy'])

#learning schedule callback
lrate = LearningRateScheduler(step_decay)
callbacks_list=[lrate]

#Fit the model
model.fit(X,encoded_Y, validation_split=0.33, epochs=50, batch_size=28, callbacks=callbacks_list, verbose=2)
# Out:
# Train on 235 samples, validate on 116 samples
# Epoch 1/50
#  - 0s - loss: 0.6803 - acc: 0.6468 - val_loss: 0.6199 - val_acc: 0.9138
# Epoch 2/50
#  - 0s - loss: 0.6195 - acc: 0.7234 - val_loss: 0.4761 - val_acc: 0.8621
# Epoch 3/50
#  - 0s - loss: 0.4985 - acc: 0.8255 - val_loss: 0.3656 - val_acc: 0.9483
# Epoch 4/50
#  - 0s - loss: 0.3623 - acc: 0.8596 - val_loss: 0.3781 - val_acc: 0.8879
# Epoch 5/50
#  - 0s - loss: 0.2791 - acc: 0.8809 - val_loss: 0.1528 - val_acc: 0.9655
# Epoch 6/50
#  - 0s - loss: 0.2181 - acc: 0.9234 - val_loss: 0.2144 - val_acc: 0.9397
# Epoch 7/50
#  - 0s - loss: 0.1797 - acc: 0.9362 - val_loss: 0.1483 - val_acc: 0.9655
# Epoch 8/50
#  - 0s - loss: 0.1586 - acc: 0.9404 - val_loss: 0.0848 - val_acc: 0.9741
# Epoch 9/50
#  - 0s - loss: 0.1828 - acc: 0.9362 - val_loss: 0.1650 - val_acc: 0.9569
# Epoch 10/50
#  - 0s - loss: 0.1267 - acc: 0.9574 - val_loss: 0.0947 - val_acc: 0.9914
# Epoch 11/50
#  - 0s - loss: 0.1146 - acc: 0.9574 - val_loss: 0.1018 - val_acc: 0.9914
# Epoch 12/50
#  - 0s - loss: 0.1055 - acc: 0.9574 - val_loss: 0.0815 - val_acc: 0.9914
# Epoch 13/50
#  - 0s - loss: 0.1107 - acc: 0.9617 - val_loss: 0.1030 - val_acc: 0.9914
# Epoch 14/50
#  - 0s - loss: 0.0983 - acc: 0.9702 - val_loss: 0.0810 - val_acc: 0.9914
# Epoch 15/50
#  - 0s - loss: 0.0963 - acc: 0.9702 - val_loss: 0.0768 - val_acc: 0.9914
# Epoch 16/50
#  - 0s - loss: 0.1003 - acc: 0.9660 - val_loss: 0.0876 - val_acc: 0.9914
# Epoch 17/50
#  - 0s - loss: 0.0879 - acc: 0.9702 - val_loss: 0.0893 - val_acc: 0.9914
# Epoch 18/50
#  - 0s - loss: 0.0820 - acc: 0.9787 - val_loss: 0.0761 - val_acc: 0.9914
# Epoch 19/50
#  - 0s - loss: 0.0789 - acc: 0.9660 - val_loss: 0.0796 - val_acc: 0.9914
# Epoch 20/50
#  - 0s - loss: 0.0778 - acc: 0.9830 - val_loss: 0.0606 - val_acc: 0.9914
# Epoch 21/50
#  - 0s - loss: 0.0762 - acc: 0.9787 - val_loss: 0.0858 - val_acc: 0.9914
# Epoch 22/50
#  - 0s - loss: 0.0725 - acc: 0.9830 - val_loss: 0.0756 - val_acc: 0.9914
# Epoch 23/50
#  - 0s - loss: 0.0718 - acc: 0.9830 - val_loss: 0.0665 - val_acc: 0.9914
# Epoch 24/50
#  - 0s - loss: 0.0696 - acc: 0.9830 - val_loss: 0.0806 - val_acc: 0.9914
# Epoch 25/50
#  - 0s - loss: 0.0670 - acc: 0.9830 - val_loss: 0.0679 - val_acc: 0.9914
# Epoch 26/50
#  - 0s - loss: 0.0665 - acc: 0.9830 - val_loss: 0.0736 - val_acc: 0.9914
# Epoch 27/50
#  - 0s - loss: 0.0642 - acc: 0.9830 - val_loss: 0.0719 - val_acc: 0.9914
# Epoch 28/50
#  - 0s - loss: 0.0639 - acc: 0.9830 - val_loss: 0.0696 - val_acc: 0.9914
# Epoch 29/50
#  - 0s - loss: 0.0624 - acc: 0.9830 - val_loss: 0.0720 - val_acc: 0.9914
# Epoch 30/50
#  - 0s - loss: 0.0616 - acc: 0.9830 - val_loss: 0.0670 - val_acc: 0.9914
# Epoch 31/50
#  - 0s - loss: 0.0610 - acc: 0.9872 - val_loss: 0.0721 - val_acc: 0.9914
# Epoch 32/50
#  - 0s - loss: 0.0600 - acc: 0.9872 - val_loss: 0.0713 - val_acc: 0.9914
# Epoch 33/50
#  - 0s - loss: 0.0593 - acc: 0.9872 - val_loss: 0.0678 - val_acc: 0.9914
# Epoch 34/50
#  - 0s - loss: 0.0593 - acc: 0.9830 - val_loss: 0.0689 - val_acc: 0.9914
# Epoch 35/50
#  - 0s - loss: 0.0592 - acc: 0.9872 - val_loss: 0.0745 - val_acc: 0.9914
# Epoch 36/50
#  - 0s - loss: 0.0578 - acc: 0.9872 - val_loss: 0.0699 - val_acc: 0.9914
# Epoch 37/50
#  - 0s - loss: 0.0575 - acc: 0.9872 - val_loss: 0.0662 - val_acc: 0.9914
# Epoch 38/50
#  - 0s - loss: 0.0576 - acc: 0.9830 - val_loss: 0.0690 - val_acc: 0.9914
# Epoch 39/50
#  - 0s - loss: 0.0570 - acc: 0.9872 - val_loss: 0.0638 - val_acc: 0.9914
# Epoch 40/50
#  - 0s - loss: 0.0563 - acc: 0.9872 - val_loss: 0.0659 - val_acc: 0.9914
# Epoch 41/50
#  - 0s - loss: 0.0556 - acc: 0.9872 - val_loss: 0.0704 - val_acc: 0.9914
# Epoch 42/50
#  - 0s - loss: 0.0557 - acc: 0.9872 - val_loss: 0.0684 - val_acc: 0.9914
# Epoch 43/50
#  - 0s - loss: 0.0555 - acc: 0.9872 - val_loss: 0.0670 - val_acc: 0.9914
# Epoch 44/50
#  - 0s - loss: 0.0553 - acc: 0.9872 - val_loss: 0.0672 - val_acc: 0.9914
# Epoch 45/50
#  - 0s - loss: 0.0553 - acc: 0.9872 - val_loss: 0.0651 - val_acc: 0.9914
# Epoch 46/50
#  - 0s - loss: 0.0551 - acc: 0.9872 - val_loss: 0.0650 - val_acc: 0.9914
# Epoch 47/50
#  - 0s - loss: 0.0557 - acc: 0.9872 - val_loss: 0.0704 - val_acc: 0.9914
# Epoch 48/50
#  - 0s - loss: 0.0544 - acc: 0.9872 - val_loss: 0.0692 - val_acc: 0.9914
# Epoch 49/50
#  - 0s - loss: 0.0544 - acc: 0.9872 - val_loss: 0.0654 - val_acc: 0.9914
# Epoch 50/50
#  - 0s - loss: 0.0541 - acc: 0.9872 - val_loss: 0.0688 - val_acc: 0.9914

# %% [markdown]
# ## Tips for using learning rate schedules
# 1. Increase the initial learning rate
# 2. Use a large momentum
# 3. Experiement with different schedules
