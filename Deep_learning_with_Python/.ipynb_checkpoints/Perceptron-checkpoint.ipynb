# %% [markdown]
# # Multilayer perceptron
# ## Nueron
# 1. Nuerons are the building blocks of nueral nets
#
# 2. A single nueron has the form described in the graph below
# ![Screen%20Shot%202018-06-02%20at%208.05.28%20AM.png](attachment:Screen%20Shot%202018-06-02%20at%208.05.28%20AM.png)
#
# 3. Weights measure how important individual features are
#
# 4. Activation : sigmoid, relu..
#
# 5. Hidden layers: the layers after the input layer
#
# ## Output layer
# The final hidden layer is called the output layer and it is responsible for outputting a value or vector of values that correspond to the format required for the problem. The choice of activation function in the output layer is strongly constrained by the type of problem that you are modeling. For example:
#
# 1. A regression problem may have a single output neuron and the neuron may have no activation function.
#
# 2. A binary classification problem may have a single output neuron and use a sigmoid activation function to output a value between 0 and 1 to represent the probability of predicting a value for the primary class. This can be turned into a crisp class value by using a threshold of 0.5 and snap values less than the threshold to 0 otherwise to 1.
# 3. A multiclass classification problem may have multiple neurons in the output layer, one for each class (e.g. three neurons for the three classes in the famous iris flowers classification problem). In this case a softmax activation function may be used to output a probability of the network predicting each of the class values. Selecting the output with the highest probability can be used to produce a crisp class classification value.
